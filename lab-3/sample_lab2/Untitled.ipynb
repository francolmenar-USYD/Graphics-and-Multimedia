# %%
#IMPORT
from imageio import imread, imsave
import matplotlib
from matplotlib import pyplot as plt
import numpy as np
#matploit inline

# %%
#Read image
print('Raw Image')
raw_img = imread('coin.png')
plt.figure(1)
plt.imshow(raw_img)
plt.show()
# Out:
# Raw Image
